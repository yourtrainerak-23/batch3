# %% [markdown]
# # Python Programming Language
#
# ## Overview
# Python is a high-level, interpreted, and general-purpose programming language created by Guido van Rossum and first released in 1991. Known for its clear syntax and readability, Python emphasizes code readability with significant whitespace.
#
# ## Key Features
# * **Easy to Learn**: Simple, clean syntax that's easy to read and write
# * **Abstraction Level**:High Level Language
# * **Interpreted**: Code is executed line by line, making debugging easier
# * **Dynamically Typed**: No need to declare variable types explicitly
# * **Object-Oriented**: Supports OOP concepts like classes, inheritance, and polymorphism
# * **Extensive Libraries**: Rich standard library and vast ecosystem of third-party packages
# * **Cross-Platform**: Runs on Windows, macOS, Linux, and more
#
# ## Common Use Cases
# * Web Development (Django, Flask)
# * Data Science & Machine Learning (pandas, NumPy, scikit-learn)
# * Automation & Scripting
# * Scientific Computing
# * Artificial Intelligence
# * Big Data Processing (PySpark)
#
# ## Popular in Databricks
# Python is widely used in Databricks for:
# * Data engineering pipelines
# * ETL operations with PySpark
# * Machine learning model development
# * Data analysis and visualization
# * Integration with Apache Spark for distributed computing

# %%
a = 24
b = "abc"
c= a+b

#compile + executed

# %%
# Data Types in Python
#String - Text
#Features - Mutability---->>>> Imutable
# Sequential

a = "I Love DE 101"
type(a)

#String Methods
#1. String (Indexing /Slicing)
print(a[4])  # indexing
print(a[-6]) # reverse indexing
print(a[0:13:2]) # slicing
print(a[3:])
print(a[-3:]) # reverse slicing
print(a[-6:-4])
#reverse the string
print(a[::-1])
a[2:6][::-1]


#Use Case - 

# Give a python code to extract First Name and Last name from an email address of this type

#FirstName.LastName@google.com

# Get the Mobile numbers wothout Cou ntry code from this text
# +919518402089

# %%
# Iterable

a = "ABC"

for j in a:
    if  j =='B':
        print(j)
    else:
        print("_")




# Use Case 
#Get all the vowels out of this string
#"Our eerie audio engineer, Louie, queueing via a radio, queued an awesome sequoia avenue video."

# %%
#If -Else

a = 1
if a > 10:
 print("a is greater than 10")
elif a == 10:
  print("a is equal to 10")
else:
  print("a is less than  10")
